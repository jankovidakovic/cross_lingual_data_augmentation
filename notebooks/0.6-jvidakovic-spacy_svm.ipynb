# %%
import spacy
nlp = spacy.load("en_core_web_trf", disable=["parser", "attribute-ruler", "ner"])
nlp.add_pipe("sentencizer")

# %%
import pandas as pd

df = pd.read_csv("../data/dummy.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0          3109        3109
# 1         20427        7826
# 2          2769        2769
# 3         20133        7532
# 4          1749        1749
#
#                                                title  \
# 0  Five Iraqi Shia, Sunni and Kurdish political p...
# 1    Millions in Yemen ‘a step away from starvation’
# 2  Police forcibly break up a protest in Malé, Ma...
# 3  Pakistan marble mine collapse kills 22; dozens...
# 4  Near the town of Ramle, Israeli archeologists ...
#
#                                                 text  \
# 0  The accord was the second step towards rebuild...
# 1  The crisis in Yemen, now in its seventh year o...
# 2  Maldives police have used pepper spray to brea...
# 3  Army rescuers take part in a rescue search for...
# 4  Hundreds of whisky and gin bottles found at re...
#
#                       event_type  \
# 0                 Sign Agreement
# 1                         Famine
# 2    Protest_Online Condemnation
# ...

# %%
from src.utils import yield_column

[i for i in yield_column(df, "text")]
# Out:
# ['The accord was the second step towards rebuilding Iraq\'s political process, Mr Maliki said, after four Kurdish and Shia parties formed a new alliance.\nA committee formed by the parties had "accomplished some solutions", he said.\nMr Maliki has been criticised in recent days by US politicians, but the White House hailed Sunday\'s deal as "an important symbol" of unity in Iraq.\n"We congratulate Iraq\'s leaders on the important agreement reached today in Baghdad... [and] their commitment to work together for the benefit of all Iraqis," said a statement issued from President George W Bush\'s Texas ranch. \'Sense of movement\'\nIssues under discussion between Iraqi politicians include holding provincial elections and easing a ban on former Baath party members in the civil service and military.\nAfter the meeting, Mr Maliki appeared at a news conference alongside Iraqi President Jalal Talabani, Sunni Vice-President Tariq al-Hashemi, Shia Vice-President Adel Abdul-Mahdi and Massoud Bar
# ...

# %%
texts = yield_column(df, "text")

# %%
sample = list(texts)[:2]

# %%
with nlp.select_pipes(enable=["sentencizer"]):
    print(nlp.pipeline)
print(nlp.pipeline)
# Out:
# [('sentencizer', <spacy.pipeline.sentencizer.Sentencizer object at 0x7fede121a600>)]
# [('transformer', <spacy_transformers.pipeline_component.Transformer object at 0x7fede1073c40>), ('tagger', <spacy.pipeline.tagger.Tagger object at 0x7fee007d5e40>), ('attribute_ruler', <spacy.pipeline.attributeruler.AttributeRuler object at 0x7fede1533380>), ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer object at 0x7fede1079d00>), ('sentencizer', <spacy.pipeline.sentencizer.Sentencizer object at 0x7fede121a600>)]

# %%
from src.spacy_pipeline import make_pipeline
from tqdm import tqdm

pipeline = make_pipeline(
    nlp=nlp,
    n_process=1,
    n_sents=25
)

result = list(map(list, tqdm(pipeline(texts=texts), desc="Pipeline", total=10)))
result
# Out:
# Pipeline:   0%|          | 0/10 [00:00<?, ?it/s]
# []

# %%
result[0]
# Out:
# ['the',
#  'accord',
#  'be',
#  'the',
#  'second',
#  'step',
#  'towards',
#  'rebuild',
#  'Iraq',
#  "'s",
#  'political',
#  'process',
#  ',',
#  'Mr',
#  'Maliki',
#  'say',
#  ',',
#  'after',
#  'four',
#  'kurdish',
#  'and',
#  'Shia',
#  'party',
#  'form',
#  'a',
#  'new',
#  'alliance',
#  '.',
#  '\n',
#  'a',
#  'committee',
#  'form',
#  'by',
#  'the',
#  'party',
#  'have',
#  '"',
#  'accomplish',
#  'some',
#  'solution',
#  '"',
#  ',',
#  'he',
#  'say',
#  '.',
#  '\n',
#  'Mr',
#  'Maliki',
#  'have',
#  'be',
#  'criticise',
#  'in',
#  'recent',
#  'day',
#  'by',
#  'US',
#  'politician',
#  ',',
#  'but',
#  'the',
#  'White',
#  'House',
#  'hail',
#  'Sunday',
#  "'s",
#  'deal',
#  'as',
#  '"',
#  'an',
#  'important',
#  'symbol',
#  '"',
#  'of',
#  'unity',
#  'in',
#  'Iraq',
#  '.',
#  '\n',
#  '"',
#  'we',
#  'congratulate',
#  'Iraq',
#  "'s",
#  'leader',
#  'on',
#  'the',
#  'important',
#  'agreement',
#  'reach',
#  'today',
#  'in',
# ...

# %%
" ".join(result[0])
# Out:
# 'the accord be the second step towards rebuild Iraq \'s political process , Mr Maliki say , after four kurdish and Shia party form a new alliance . \n a committee form by the party have " accomplish some solution " , he say . \n Mr Maliki have be criticise in recent day by US politician , but the White House hail Sunday \'s deal as " an important symbol " of unity in Iraq . \n " we congratulate Iraq \'s leader on the important agreement reach today in Baghdad ... [ and ] their commitment to work together for the benefit of all Iraqis , " say a statement issue from President George W Bush \'s Texas ranch . \' sense of movement \' \n issue under discussion between iraqi politician include hold provincial election and ease a ban on former Baath party member in the civil service and military . \n after the meeting , Mr Maliki appear at a news conference alongside iraqi President Jalal Talabani , sunni Vice - President Tariq al - Hashemi , Shia Vice - President Adel Abdul - Mahdi and Mass
# ...
